# %% [markdown]
# <a href="https://colab.research.google.com/github/Tawanss/text-analytic-/blob/main/Copy_of_Project1_66.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Text Analytics

# %% [markdown]
# <img src="https://www.datanami.com/wp-content/uploads/2014/06/text-analytics.png" width="300">

# %% [markdown]
# ## Due Date: Sunday, October 1, 2023
# <br>
# <span style="color:red">NOTE: There are always last minute issues submitting the case studies. DO NOT WAIT UNTIL THE LAST MINUTE!</span>

# %% [markdown]
# ## List team members:

# %% [markdown]
# 1. Tawan       643020501-6 Tawan.b@kkumail.com
# 2. Punnita Thongbor    643020508-2 Punnita.t@kkumail.com
# 3. Puttipong   643021268-1 Puttipongyy@kkumail.com
# 4. Satawat     643021273-8 Satawat.m@kkumail.com
# 5. Jindaporn Phopomee  643021262-3 Jindaporn.p@kkumail.com

# %%
# Out:
# 3

# %% [markdown]
# **NOTE1**: Please don't forget to save the notebook frequently when working in IPython Notebook, otherwise the changes you made can be lost
#
# **NOTE2**: Create a slide presentation once finished, convert to pdf format, and turn in by one group member only
# <br>A list of documents to turn in: 1) Jupyter notebook containing results and 2) A set of slides in pdf format

# %% [raw]
# !pip3 install wordcloud

# %%
# Load these libraries
import json
import pprint
import pandas as pd
from io import StringIO # using StringIO to prevent ValueError
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import urllib.request

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Problem 1: Working with Twitter Data and JSON file

# %% [markdown]
# We are working with a Twitter dataset in JSON format from `thailand_tweets.txt`.<br>
# The tweets were scraped using "Thailand" keyword on August 31, 2022.<br>
# We are going to examine the dataset and retrieve information from the JSON file.
# Most Twitter datasets provide only Tweet ID where we can retrieve tweets from tweet ID as follow.
# ```
# twitter.com/anyuser/status/<tweet_id>
# ```

# %% [markdown]
# #### Read JSON file

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-3-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
#     134     )
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in blocking_request(request_type, request, timeout_sec, parent)
#     174       request_type, request, parent=parent, expect_reply=True
#     175   )
# --> 176   return read_reply_from_input(request_id, timeout_sec)
#
# /usr/local/lib/python3.10/dist-packages/google/colab/_message.py in read_reply_from_input(message_id, timeout_sec)
#     101     ):
#     102       if 'error' in reply:
# --> 103         raise MessageError(reply['error'])
#     104       return reply.get('data', None)
#     105
#
# MessageError: Error: credential propagation was unsuccessful

# %%
# read the file
file = open('/content/drive/MyDrive/DataForBig/thailand_tweets.txt','r') # rename
foo = file.read()
d = json.loads(foo)

# %%
thailand_json = json.loads(d)
thailand_json
# Out:
# {'1564764893038882816': {'tweet_id': '1564764893038882816',
#   'username': 'matthunter',
#   'name': 'MATT HUNTΞR',
#   'profile_picture': 'https://twitter.com/matthunter/photo',
#   'replies': 2,
#   'retweets': 1,
#   'likes': 7,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:59:57+00:00',
#   'content': 'Thanks for asking! Yes, we will support shipping to most countries, including Japan and Thailand. ',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/matthunter/status/1564764893038882816',
#   'link': ''},
#  '1564764866598080513': {'tweet_id': '1564764866598080513',
#   'username': 'DavSmithVP',
#   'name': 'DavSmith / Virtual Photography',
#   'profile_picture': 'https://twitter.com/DavSmithVP/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 2,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:59:50+00:00',
#   'content': 'Tomb Raider Underworld | Thailand \n#VirtualPhotography \n@tombraider\n @crystaldynamics',
#   'hashtags': ['VirtualPhotography'],
#   'mentions': ['tombraider', 'crystaldynamics'],
#   'images': ['https://pbs.twimg.com/media/FbcpF-FXkAIlqTS?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/DavSmithVP/status/1564764866598080513',
#   'link': ''},
#  '1564764845685280772': {'tweet_id': '1564764845685280772',
#   'username': 'DailyPattaya',
#   'name': 'The Pattaya Daily',
#   'profile_picture': 'https://twitter.com/DailyPattaya/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:59:45+00:00',
#   'content': 'The latest The Pattaya Daily! http://thepattayadaily.com Thanks to \n@PopeKael\n @ASEANNOWTH\n #thailand #pattaya',
#   'hashtags': ['thailand', 'pattaya'],
#   'mentions': ['PopeKael', 'ASEANNOWTH'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/DailyPattaya/status/1564764845685280772',
#   'link': ''},
#  '1564764710804897792': {'tweet_id': '1564764710804897792',
#   'username': 'Bryan62766077',
#   'name': 'Bryan',
#   'profile_picture': 'https://twitter.com/Bryan62766077/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 1,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:59:13+00:00',
#   'content': 'You can live some places for next to nothing, believe it or not. I pay $300 a month for a really nice apartment in Thailand. All utilities included. No deposit. Close to the beach. Live music clubs everywhere. Meals are about $2',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Bryan62766077/status/1564764710804897792',
#   'link': ''},
#  '1564764468277612549': {'tweet_id': '1564764468277612549',
#   'username': 'Megan_and_Grrr',
#   'name': 'Megan',
#   'profile_picture': 'https://twitter.com/Megan_and_Grrr/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:58:15+00:00',
#   'content': "ALIEN HOUSE is a story of love, hope and alien intervention set in Wales, Thailand and Inner Space. It's a #fantasy story about #extraterrestrial contact and the conflict between a man and his inner voice or alter ego. William is not sure if he's going mad https://smarturl.it/alien-house-eng?IQid=jbmegan…",
#   'hashtags': ['fantasy', 'extraterrestrial'],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/Fbco_bSXEAMcDOZ?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Megan_and_Grrr/status/1564764468277612549',
#   'link': ''},
#  '1564764445825458181': {'tweet_id': '1564764445825458181',
#   'username': 'OhmPawatInter',
#   'name': 'OhmPawat International',
#   'profile_picture': 'https://twitter.com/OhmPawatInter/photo',
#   'replies': 0,
#   'retweets': 99,
#   'likes': 143,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:58:10+00:00',
#   'content': 'Trend twitter update \n\nTop Twitter influencers in Thailand today \n#4 \n@ohmpawatt\nInfluence Score: 19442\n7 top tweets\n25182 retweets\n\nhttps://etrenders.com/trendsetters/Thailand…\n#ohmpawat #ยิ้ม5พันของโอมภวัต',
#   'hashtags': ['4', 'ohmpawat', 'ย'],
#   'mentions': ['ohmpawatt'],
#   'images': ['https://pbs.twimg.com/media/Fbco99jWIAEd3Oe?format=jpg&name=small',
#    'https://pbs.twimg.com/media/Fbco-JwWYAE7oLy?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/OhmPawatInter/status/1564764445825458181',
#   'link': ''},
#  '1564764361742110720': {'tweet_id': '1564764361742110720',
#   'username': 'nato_tonyo11',
#   'name': 'nutri(BUSY SI ENGR.)| SoliD',
#   'profile_picture': 'https://twitter.com/nato_tonyo11/photo',
#   'replies': 0,
#   'retweets': 2,
#   'likes': 18,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:57:50+00:00',
#   'content': 'Good morning  world! And goodmorning to you too #DonnyPangilinan, enjoy Thailand babe and please do take selfies out there!, pagod nakong makikitang sapatos pa din nasa igs mo!!',
#   'hashtags': ['DonnyPangilinan'],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/nato_tonyo11/status/1564764361742110720',
#   'link': ''},
#  '1564764274098323456': {'tweet_id': '1564764274098323456',
#   'username': 'ThThitikarn61',
#   'name': 'thiti',
#   'profile_picture': 'https://twitter.com/ThThitikarn61/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:57:29+00:00',
#   'content': 'Listening to #faraway the title track of #theotherside album by #MarkTuan \n@marktuan\n while traveling to Thailand',
#   'hashtags': ['faraway', 'theotherside', 'MarkTuan'],
#   'mentions': ['marktuan'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/ThThitikarn61/status/1564764274098323456',
#   'link': ''},
#  '1564764028014313472': {'tweet_id': '1564764028014313472',
#   'username': 'Livetradingnews',
#   'name': 'Knightly News',
#   'profile_picture': 'https://twitter.com/Livetradingnews/photo',
#   'replies': 0,
#   'retweets': 2,
#   'likes': 3,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:56:30+00:00',
#   'content': "With the recent news of the SCB X-Bitkub deal falling apart and the Zipmex incident, investors in Thailand's digital currency market are facing a negative outlook",
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Livetradingnews/status/1564764028014313472',
#   'link': ''},
#  '1564763907700531202': {'tweet_id': '1564763907700531202',
#   'username': 'DiscoverSoc',
#   'name': 'Discover Society',
#   'profile_picture': 'https://twitter.com/DiscoverSoc/photo',
#   'replies': 0,
#   'retweets': 1,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:56:02+00:00',
#   'content': '#ICYMI  On the Frontline. Crude Power in Thailand’s 2014 Coup: Old Soldiers Almost Die',
#   'hashtags': ['ICYMI'],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/DiscoverSoc/status/1564763907700531202',
#   'link': 'https://t.co/OYQzv4BSm9'},
#  '1564763775403712513': {'tweet_id': '1564763775403712513',
#   'username': 'Onside10900651',
#   'name': 'Onside',
#   'profile_picture': 'https://twitter.com/Onside10900651/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:55:30+00:00',
#   'content': 'And I thought Thailand was absolutely democratic?',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Onside10900651/status/1564763775403712513',
#   'link': ''},
#  '1564763746463105026': {'tweet_id': '1564763746463105026',
#   'username': 'lekwilliams',
#   'name': 'Lek',
#   'profile_picture': 'https://twitter.com/lekwilliams/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:55:23+00:00',
#   'content': "How far would you go to save the family farm and keep your siblings in school? Read what Lek did in 'Behind The Smile, the story of Lek, a bar girl in Pattaya' by Owen Jones! https://smarturl.it/BTS-boxset?IQid=SJB-lw-thailand… #pattaya #Thailand Please retweet",
#   'hashtags': ['pattaya', 'Thailand'],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/FbcoVHpWIAEh_R0?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/lekwilliams/status/1564763746463105026',
#   'link': ''},
#  '1564763729967054848': {'tweet_id': '1564763729967054848',
#   'username': 'o_rung_o1',
#   'name': 'o_Rung_o',
#   'profile_picture': 'https://twitter.com/o_rung_o1/photo',
#   'replies': 0,
#   'retweets': 28,
#   'likes': 15,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:55:19+00:00',
#   'content': 'วันนี้วันสุดท้ายของการโหวต รางวัล Outstanding Asian Star Thailand #SDA2022 ให้น้องพีพีแล้วนะคะ \nมาพาน้องไปรับถ้วยรางวัล2ปีซ้อนกันค่ะ\n#voteforppkritt \n#ppkritt',
#   'hashtags': ['SDA2022', 'voteforppkritt', 'ppkritt'],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/FbcoUQAaQAAIFME?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/o_rung_o1/status/1564763729967054848',
#   'link': ''},
#  '1564763679232405504': {'tweet_id': '1564763679232405504',
#   'username': 'sixhav',
#   'name': 'shi bangs',
#   'profile_picture': 'https://twitter.com/sixhav/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 1,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:55:07+00:00',
#   'content': 'right? 2 years ago he is just a simple born and raised guy from thailand who can barely speak thai and likes to do diys and make everything about math i just love how authentic he is hahaha have you seen his 1000 push ups one? ',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/sixhav/status/1564763679232405504',
#   'link': ''},
#  '1564763673662464003': {'tweet_id': '1564763673662464003',
#   'username': 'JaeJazee',
#   'name': 'ⒷⓉⓈARMY할머니ᴶᴹᴶᴷ³ᴶ',
#   'profile_picture': 'https://twitter.com/JaeJazee/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:55:06+00:00',
#   'content': 'I knew I heard the beginning speech that Lisa had an Australian accent.  It is not that she is from Australia but Thailand... here is the explanation...',
#   'hashtags': [],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/FbcoKGTWAAAA0-D?format=png&name=900x900'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/JaeJazee/status/1564763673662464003',
#   'link': ''},
#  '1564763553130655744': {'tweet_id': '1564763553130655744',
#   'username': 'chak4793',
#   'name': '¢нαк.єтн',
#   'profile_picture': 'https://twitter.com/chak4793/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 7,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:54:37+00:00',
#   'content': 'Can fluf merch send to Asian countries like Japan or Thailand?',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/chak4793/status/1564763553130655744',
#   'link': ''},
#  '1564763407818952705': {'tweet_id': '1564763407818952705',
#   'username': 'SarahJa56317435',
#   'name': 'j',
#   'profile_picture': 'https://twitter.com/SarahJa56317435/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:54:02+00:00',
#   'content': "= and the French people and also Thailand's people that have not thrown lethal military barracks gas at an 'Enemy of Thought' are the races to not survive a space race Masterclass",
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/SarahJa56317435/status/1564763407818952705',
#   'link': ''},
#  '1564763389058027521': {'tweet_id': '1564763389058027521',
#   'username': 'starrykws',
#   'name': 'em ☾',
#   'profile_picture': 'https://twitter.com/starrykws/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:53:58+00:00',
#   'content': 'woo.ddadda in thailand ',
#   'hashtags': [],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/FbcoAO_XkAA-Isn?format=jpg&name=360x360',
#    'https://pbs.twimg.com/media/FbcoAPDXEAYc26T?format=jpg&name=360x360'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/starrykws/status/1564763389058027521',
#   'link': ''},
#  '1564763303989366784': {'tweet_id': '1564763303989366784',
#   'username': 'aisseutea',
#   'name': 'Cynthia Dewi',
#   'profile_picture': 'https://twitter.com/aisseutea/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:53:38+00:00',
#   'content': 'Kalo di thailand bukan dong :)',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/aisseutea/status/1564763303989366784',
#   'link': ''},
#  '1564763292354355200': {'tweet_id': '1564763292354355200',
#   'username': 'LDN327',
#   'name': 'LDN327',
#   'profile_picture': 'https://twitter.com/LDN327/photo',
#   'replies': 1,
#   'retweets': 7,
#   'likes': 5,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:53:35+00:00',
#   'content': '- please engage\n\nELLE Thailand  \n https://instagram.com/p/Ch02SH7hGpq/ \n  https://instagram.com/p/Ch0xESZB1kr/ \n\n#LISA #LALISA #Money',
#   'hashtags': ['LISA', 'LALISA', 'Money'],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/LDN327/status/1564763292354355200',
#   'link': 'https://t.co/6aZ539h9RK'},
#  '1564763185244426240': {'tweet_id': '1564763185244426240',
#   'username': 'Jay_beebee',
#   'name': 'Jay Bee',
#   'profile_picture': 'https://twitter.com/Jay_beebee/photo',
#   'replies': 1,
#   'retweets': 7,
#   'likes': 7,
#   'is_retweet': True,
#   'posted_time': '2022-08-30T23:53:09+00:00',
#   'content': 'พร้อมครัช\n\nPlease,come to thailand.\n \n\n#JAYB #제이비 \n@jaybnow_hr\n#GOT7 #갓세븐 \n@GOT7\n#CDNZA \n@cdnzarecords\n#Def',
#   'hashtags': ['JAYB', '제이비', 'GOT7', '갓세븐', 'CDNZA', 'Def'],
#   'mentions': ['jaybnow_hr', 'GOT7', 'cdnzarecords'],
#   'images': ['https://pbs.twimg.com/media/FbcmB6RUEAA75m6?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Jay_beebee/status/1564763185244426240',
#   'link': ''},
#  '1564763141589897217': {'tweet_id': '1564763141589897217',
#   'username': 'Iovelydoll',
#   'name': '',
#   'profile_picture': 'https://twitter.com/Iovelydoll/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 3,
#   'is_retweet': True,
#   'posted_time': '2022-08-30T23:52:59+00:00',
#   'content': 'we need more ten vlogs in thailand...a girl can dream',
#   'hashtags': [],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/EDNptiHUEAAqdwm?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Iovelydoll/status/1564763141589897217',
#   'link': ''},
#  '1564763050477244417': {'tweet_id': '1564763050477244417',
#   'username': 'jaemmrchv',
#   'name': 'wonyoungiii | surprise cutie',
#   'profile_picture': 'https://twitter.com/jaemmrchv/photo',
#   'replies': 0,
#   'retweets': 1,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:52:37+00:00',
#   'content': '@NaEMwi\n @jaemwinner\n @JAEMIN_THAILAND',
#   'hashtags': [],
#   'mentions': ['NaEMwi', 'jaemwinner', 'JAEMIN_THAILAND'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/jaemmrchv/status/1564763050477244417',
#   'link': ''},
#  '1564762341324992513': {'tweet_id': '1564762341324992513',
#   'username': 'Zeepruk_jfc',
#   'name': 'ZeePruk_JapanFC（Rest）',
#   'profile_picture': 'https://twitter.com/Zeepruk_jfc/photo',
#   'replies': 2,
#   'retweets': 54,
#   'likes': 32,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:49:48+00:00',
#   'content': "Can you help me?\n\ntracking number\nFMP200001150XX\n\nDoes anyone know a shipping company in Thailand that handles this number?\nI'm in trouble with no reply even if I contact the caller \n\n#Zunshine",
#   'hashtags': ['Zunshine'],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Zeepruk_jfc/status/1564762341324992513',
#   'link': ''},
#  '1564762335192940544': {'tweet_id': '1564762335192940544',
#   'username': 'NFTLadyEve',
#   'name': 'NFTeVe',
#   'profile_picture': 'https://twitter.com/NFTLadyEve/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 1,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:49:47+00:00',
#   'content': 'how about Friday at 11 am? that way it will  be 10pm in Thailand & we can invite that crew.\n@blossom_melonn',
#   'hashtags': [],
#   'mentions': ['blossom_melonn'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/NFTLadyEve/status/1564762335192940544',
#   'link': ''},
#  '1564762170277052418': {'tweet_id': '1564762170277052418',
#   'username': 'AntzAntz1',
#   'name': 'palito..showcase',
#   'profile_picture': 'https://twitter.com/AntzAntz1/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:49:07+00:00',
#   'content': 'เป๊ก ปาล์มมี่ | Disney+ Hotstar Thailand https://youtu.be/541HmrdzmHc via \n@YouTube\n  #เปกผลิตโชค #PeckPaLitChoke',
#   'hashtags': ['เปกผล', 'PeckPaLitChoke'],
#   'mentions': ['YouTube'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/AntzAntz1/status/1564762170277052418',
#   'link': ''},
#  '1564762027507458049': {'tweet_id': '1564762027507458049',
#   'username': 'taraxacumyx',
#   'name': 'Dandelion',
#   'profile_picture': 'https://twitter.com/taraxacumyx/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:48:33+00:00',
#   'content': '@blueeyellowww\n Yuk nabung buat ke Thailand wkwk',
#   'hashtags': [],
#   'mentions': ['blueeyellowww'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/taraxacumyx/status/1564762027507458049',
#   'link': ''},
#  '1564761944061382656': {'tweet_id': '1564761944061382656',
#   'username': 'IrfanHazard10',
#   'name': 'Irfan Rapiansyah',
#   'profile_picture': 'https://twitter.com/IrfanHazard10/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:48:13+00:00',
#   'content': 'Padahal berharap pertama lawan Thailand atau Filipina',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/IrfanHazard10/status/1564761944061382656',
#   'link': ''},
#  '1564761905410875392': {'tweet_id': '1564761905410875392',
#   'username': 'moanfIeur',
#   'name': '',
#   'profile_picture': 'https://twitter.com/moanfIeur/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:48:04+00:00',
#   'content': 'Tinggal cari duitnya aja ini mah kalo di Thailand bisa pake Qris',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/moanfIeur/status/1564761905410875392',
#   'link': ''}}

# %%
# inspect the file
thailand_json
# Out:
# {'1564764893038882816': {'tweet_id': '1564764893038882816',
#   'username': 'matthunter',
#   'name': 'MATT HUNTΞR',
#   'profile_picture': 'https://twitter.com/matthunter/photo',
#   'replies': 2,
#   'retweets': 1,
#   'likes': 7,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:59:57+00:00',
#   'content': 'Thanks for asking! Yes, we will support shipping to most countries, including Japan and Thailand. ',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/matthunter/status/1564764893038882816',
#   'link': ''},
#  '1564764866598080513': {'tweet_id': '1564764866598080513',
#   'username': 'DavSmithVP',
#   'name': 'DavSmith / Virtual Photography',
#   'profile_picture': 'https://twitter.com/DavSmithVP/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 2,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:59:50+00:00',
#   'content': 'Tomb Raider Underworld | Thailand \n#VirtualPhotography \n@tombraider\n @crystaldynamics',
#   'hashtags': ['VirtualPhotography'],
#   'mentions': ['tombraider', 'crystaldynamics'],
#   'images': ['https://pbs.twimg.com/media/FbcpF-FXkAIlqTS?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/DavSmithVP/status/1564764866598080513',
#   'link': ''},
#  '1564764845685280772': {'tweet_id': '1564764845685280772',
#   'username': 'DailyPattaya',
#   'name': 'The Pattaya Daily',
#   'profile_picture': 'https://twitter.com/DailyPattaya/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:59:45+00:00',
#   'content': 'The latest The Pattaya Daily! http://thepattayadaily.com Thanks to \n@PopeKael\n @ASEANNOWTH\n #thailand #pattaya',
#   'hashtags': ['thailand', 'pattaya'],
#   'mentions': ['PopeKael', 'ASEANNOWTH'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/DailyPattaya/status/1564764845685280772',
#   'link': ''},
#  '1564764710804897792': {'tweet_id': '1564764710804897792',
#   'username': 'Bryan62766077',
#   'name': 'Bryan',
#   'profile_picture': 'https://twitter.com/Bryan62766077/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 1,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:59:13+00:00',
#   'content': 'You can live some places for next to nothing, believe it or not. I pay $300 a month for a really nice apartment in Thailand. All utilities included. No deposit. Close to the beach. Live music clubs everywhere. Meals are about $2',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Bryan62766077/status/1564764710804897792',
#   'link': ''},
#  '1564764468277612549': {'tweet_id': '1564764468277612549',
#   'username': 'Megan_and_Grrr',
#   'name': 'Megan',
#   'profile_picture': 'https://twitter.com/Megan_and_Grrr/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:58:15+00:00',
#   'content': "ALIEN HOUSE is a story of love, hope and alien intervention set in Wales, Thailand and Inner Space. It's a #fantasy story about #extraterrestrial contact and the conflict between a man and his inner voice or alter ego. William is not sure if he's going mad https://smarturl.it/alien-house-eng?IQid=jbmegan…",
#   'hashtags': ['fantasy', 'extraterrestrial'],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/Fbco_bSXEAMcDOZ?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Megan_and_Grrr/status/1564764468277612549',
#   'link': ''},
#  '1564764445825458181': {'tweet_id': '1564764445825458181',
#   'username': 'OhmPawatInter',
#   'name': 'OhmPawat International',
#   'profile_picture': 'https://twitter.com/OhmPawatInter/photo',
#   'replies': 0,
#   'retweets': 99,
#   'likes': 143,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:58:10+00:00',
#   'content': 'Trend twitter update \n\nTop Twitter influencers in Thailand today \n#4 \n@ohmpawatt\nInfluence Score: 19442\n7 top tweets\n25182 retweets\n\nhttps://etrenders.com/trendsetters/Thailand…\n#ohmpawat #ยิ้ม5พันของโอมภวัต',
#   'hashtags': ['4', 'ohmpawat', 'ย'],
#   'mentions': ['ohmpawatt'],
#   'images': ['https://pbs.twimg.com/media/Fbco99jWIAEd3Oe?format=jpg&name=small',
#    'https://pbs.twimg.com/media/Fbco-JwWYAE7oLy?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/OhmPawatInter/status/1564764445825458181',
#   'link': ''},
#  '1564764361742110720': {'tweet_id': '1564764361742110720',
#   'username': 'nato_tonyo11',
#   'name': 'nutri(BUSY SI ENGR.)| SoliD',
#   'profile_picture': 'https://twitter.com/nato_tonyo11/photo',
#   'replies': 0,
#   'retweets': 2,
#   'likes': 18,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:57:50+00:00',
#   'content': 'Good morning  world! And goodmorning to you too #DonnyPangilinan, enjoy Thailand babe and please do take selfies out there!, pagod nakong makikitang sapatos pa din nasa igs mo!!',
#   'hashtags': ['DonnyPangilinan'],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/nato_tonyo11/status/1564764361742110720',
#   'link': ''},
#  '1564764274098323456': {'tweet_id': '1564764274098323456',
#   'username': 'ThThitikarn61',
#   'name': 'thiti',
#   'profile_picture': 'https://twitter.com/ThThitikarn61/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:57:29+00:00',
#   'content': 'Listening to #faraway the title track of #theotherside album by #MarkTuan \n@marktuan\n while traveling to Thailand',
#   'hashtags': ['faraway', 'theotherside', 'MarkTuan'],
#   'mentions': ['marktuan'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/ThThitikarn61/status/1564764274098323456',
#   'link': ''},
#  '1564764028014313472': {'tweet_id': '1564764028014313472',
#   'username': 'Livetradingnews',
#   'name': 'Knightly News',
#   'profile_picture': 'https://twitter.com/Livetradingnews/photo',
#   'replies': 0,
#   'retweets': 2,
#   'likes': 3,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:56:30+00:00',
#   'content': "With the recent news of the SCB X-Bitkub deal falling apart and the Zipmex incident, investors in Thailand's digital currency market are facing a negative outlook",
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Livetradingnews/status/1564764028014313472',
#   'link': ''},
#  '1564763907700531202': {'tweet_id': '1564763907700531202',
#   'username': 'DiscoverSoc',
#   'name': 'Discover Society',
#   'profile_picture': 'https://twitter.com/DiscoverSoc/photo',
#   'replies': 0,
#   'retweets': 1,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:56:02+00:00',
#   'content': '#ICYMI  On the Frontline. Crude Power in Thailand’s 2014 Coup: Old Soldiers Almost Die',
#   'hashtags': ['ICYMI'],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/DiscoverSoc/status/1564763907700531202',
#   'link': 'https://t.co/OYQzv4BSm9'},
#  '1564763775403712513': {'tweet_id': '1564763775403712513',
#   'username': 'Onside10900651',
#   'name': 'Onside',
#   'profile_picture': 'https://twitter.com/Onside10900651/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:55:30+00:00',
#   'content': 'And I thought Thailand was absolutely democratic?',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Onside10900651/status/1564763775403712513',
#   'link': ''},
#  '1564763746463105026': {'tweet_id': '1564763746463105026',
#   'username': 'lekwilliams',
#   'name': 'Lek',
#   'profile_picture': 'https://twitter.com/lekwilliams/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:55:23+00:00',
#   'content': "How far would you go to save the family farm and keep your siblings in school? Read what Lek did in 'Behind The Smile, the story of Lek, a bar girl in Pattaya' by Owen Jones! https://smarturl.it/BTS-boxset?IQid=SJB-lw-thailand… #pattaya #Thailand Please retweet",
#   'hashtags': ['pattaya', 'Thailand'],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/FbcoVHpWIAEh_R0?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/lekwilliams/status/1564763746463105026',
#   'link': ''},
#  '1564763729967054848': {'tweet_id': '1564763729967054848',
#   'username': 'o_rung_o1',
#   'name': 'o_Rung_o',
#   'profile_picture': 'https://twitter.com/o_rung_o1/photo',
#   'replies': 0,
#   'retweets': 28,
#   'likes': 15,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:55:19+00:00',
#   'content': 'วันนี้วันสุดท้ายของการโหวต รางวัล Outstanding Asian Star Thailand #SDA2022 ให้น้องพีพีแล้วนะคะ \nมาพาน้องไปรับถ้วยรางวัล2ปีซ้อนกันค่ะ\n#voteforppkritt \n#ppkritt',
#   'hashtags': ['SDA2022', 'voteforppkritt', 'ppkritt'],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/FbcoUQAaQAAIFME?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/o_rung_o1/status/1564763729967054848',
#   'link': ''},
#  '1564763679232405504': {'tweet_id': '1564763679232405504',
#   'username': 'sixhav',
#   'name': 'shi bangs',
#   'profile_picture': 'https://twitter.com/sixhav/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 1,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:55:07+00:00',
#   'content': 'right? 2 years ago he is just a simple born and raised guy from thailand who can barely speak thai and likes to do diys and make everything about math i just love how authentic he is hahaha have you seen his 1000 push ups one? ',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/sixhav/status/1564763679232405504',
#   'link': ''},
#  '1564763673662464003': {'tweet_id': '1564763673662464003',
#   'username': 'JaeJazee',
#   'name': 'ⒷⓉⓈARMY할머니ᴶᴹᴶᴷ³ᴶ',
#   'profile_picture': 'https://twitter.com/JaeJazee/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:55:06+00:00',
#   'content': 'I knew I heard the beginning speech that Lisa had an Australian accent.  It is not that she is from Australia but Thailand... here is the explanation...',
#   'hashtags': [],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/FbcoKGTWAAAA0-D?format=png&name=900x900'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/JaeJazee/status/1564763673662464003',
#   'link': ''},
#  '1564763553130655744': {'tweet_id': '1564763553130655744',
#   'username': 'chak4793',
#   'name': '¢нαк.єтн',
#   'profile_picture': 'https://twitter.com/chak4793/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 7,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:54:37+00:00',
#   'content': 'Can fluf merch send to Asian countries like Japan or Thailand?',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/chak4793/status/1564763553130655744',
#   'link': ''},
#  '1564763407818952705': {'tweet_id': '1564763407818952705',
#   'username': 'SarahJa56317435',
#   'name': 'j',
#   'profile_picture': 'https://twitter.com/SarahJa56317435/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:54:02+00:00',
#   'content': "= and the French people and also Thailand's people that have not thrown lethal military barracks gas at an 'Enemy of Thought' are the races to not survive a space race Masterclass",
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/SarahJa56317435/status/1564763407818952705',
#   'link': ''},
#  '1564763389058027521': {'tweet_id': '1564763389058027521',
#   'username': 'starrykws',
#   'name': 'em ☾',
#   'profile_picture': 'https://twitter.com/starrykws/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:53:58+00:00',
#   'content': 'woo.ddadda in thailand ',
#   'hashtags': [],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/FbcoAO_XkAA-Isn?format=jpg&name=360x360',
#    'https://pbs.twimg.com/media/FbcoAPDXEAYc26T?format=jpg&name=360x360'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/starrykws/status/1564763389058027521',
#   'link': ''},
#  '1564763303989366784': {'tweet_id': '1564763303989366784',
#   'username': 'aisseutea',
#   'name': 'Cynthia Dewi',
#   'profile_picture': 'https://twitter.com/aisseutea/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:53:38+00:00',
#   'content': 'Kalo di thailand bukan dong :)',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/aisseutea/status/1564763303989366784',
#   'link': ''},
#  '1564763292354355200': {'tweet_id': '1564763292354355200',
#   'username': 'LDN327',
#   'name': 'LDN327',
#   'profile_picture': 'https://twitter.com/LDN327/photo',
#   'replies': 1,
#   'retweets': 7,
#   'likes': 5,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:53:35+00:00',
#   'content': '- please engage\n\nELLE Thailand  \n https://instagram.com/p/Ch02SH7hGpq/ \n  https://instagram.com/p/Ch0xESZB1kr/ \n\n#LISA #LALISA #Money',
#   'hashtags': ['LISA', 'LALISA', 'Money'],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/LDN327/status/1564763292354355200',
#   'link': 'https://t.co/6aZ539h9RK'},
#  '1564763185244426240': {'tweet_id': '1564763185244426240',
#   'username': 'Jay_beebee',
#   'name': 'Jay Bee',
#   'profile_picture': 'https://twitter.com/Jay_beebee/photo',
#   'replies': 1,
#   'retweets': 7,
#   'likes': 7,
#   'is_retweet': True,
#   'posted_time': '2022-08-30T23:53:09+00:00',
#   'content': 'พร้อมครัช\n\nPlease,come to thailand.\n \n\n#JAYB #제이비 \n@jaybnow_hr\n#GOT7 #갓세븐 \n@GOT7\n#CDNZA \n@cdnzarecords\n#Def',
#   'hashtags': ['JAYB', '제이비', 'GOT7', '갓세븐', 'CDNZA', 'Def'],
#   'mentions': ['jaybnow_hr', 'GOT7', 'cdnzarecords'],
#   'images': ['https://pbs.twimg.com/media/FbcmB6RUEAA75m6?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Jay_beebee/status/1564763185244426240',
#   'link': ''},
#  '1564763141589897217': {'tweet_id': '1564763141589897217',
#   'username': 'Iovelydoll',
#   'name': '',
#   'profile_picture': 'https://twitter.com/Iovelydoll/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 3,
#   'is_retweet': True,
#   'posted_time': '2022-08-30T23:52:59+00:00',
#   'content': 'we need more ten vlogs in thailand...a girl can dream',
#   'hashtags': [],
#   'mentions': [],
#   'images': ['https://pbs.twimg.com/media/EDNptiHUEAAqdwm?format=jpg&name=small'],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Iovelydoll/status/1564763141589897217',
#   'link': ''},
#  '1564763050477244417': {'tweet_id': '1564763050477244417',
#   'username': 'jaemmrchv',
#   'name': 'wonyoungiii | surprise cutie',
#   'profile_picture': 'https://twitter.com/jaemmrchv/photo',
#   'replies': 0,
#   'retweets': 1,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:52:37+00:00',
#   'content': '@NaEMwi\n @jaemwinner\n @JAEMIN_THAILAND',
#   'hashtags': [],
#   'mentions': ['NaEMwi', 'jaemwinner', 'JAEMIN_THAILAND'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/jaemmrchv/status/1564763050477244417',
#   'link': ''},
#  '1564762341324992513': {'tweet_id': '1564762341324992513',
#   'username': 'Zeepruk_jfc',
#   'name': 'ZeePruk_JapanFC（Rest）',
#   'profile_picture': 'https://twitter.com/Zeepruk_jfc/photo',
#   'replies': 2,
#   'retweets': 54,
#   'likes': 32,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:49:48+00:00',
#   'content': "Can you help me?\n\ntracking number\nFMP200001150XX\n\nDoes anyone know a shipping company in Thailand that handles this number?\nI'm in trouble with no reply even if I contact the caller \n\n#Zunshine",
#   'hashtags': ['Zunshine'],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/Zeepruk_jfc/status/1564762341324992513',
#   'link': ''},
#  '1564762335192940544': {'tweet_id': '1564762335192940544',
#   'username': 'NFTLadyEve',
#   'name': 'NFTeVe',
#   'profile_picture': 'https://twitter.com/NFTLadyEve/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 1,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:49:47+00:00',
#   'content': 'how about Friday at 11 am? that way it will  be 10pm in Thailand & we can invite that crew.\n@blossom_melonn',
#   'hashtags': [],
#   'mentions': ['blossom_melonn'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/NFTLadyEve/status/1564762335192940544',
#   'link': ''},
#  '1564762170277052418': {'tweet_id': '1564762170277052418',
#   'username': 'AntzAntz1',
#   'name': 'palito..showcase',
#   'profile_picture': 'https://twitter.com/AntzAntz1/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:49:07+00:00',
#   'content': 'เป๊ก ปาล์มมี่ | Disney+ Hotstar Thailand https://youtu.be/541HmrdzmHc via \n@YouTube\n  #เปกผลิตโชค #PeckPaLitChoke',
#   'hashtags': ['เปกผล', 'PeckPaLitChoke'],
#   'mentions': ['YouTube'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/AntzAntz1/status/1564762170277052418',
#   'link': ''},
#  '1564762027507458049': {'tweet_id': '1564762027507458049',
#   'username': 'taraxacumyx',
#   'name': 'Dandelion',
#   'profile_picture': 'https://twitter.com/taraxacumyx/photo',
#   'replies': 1,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:48:33+00:00',
#   'content': '@blueeyellowww\n Yuk nabung buat ke Thailand wkwk',
#   'hashtags': [],
#   'mentions': ['blueeyellowww'],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/taraxacumyx/status/1564762027507458049',
#   'link': ''},
#  '1564761944061382656': {'tweet_id': '1564761944061382656',
#   'username': 'IrfanHazard10',
#   'name': 'Irfan Rapiansyah',
#   'profile_picture': 'https://twitter.com/IrfanHazard10/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:48:13+00:00',
#   'content': 'Padahal berharap pertama lawan Thailand atau Filipina',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/IrfanHazard10/status/1564761944061382656',
#   'link': ''},
#  '1564761905410875392': {'tweet_id': '1564761905410875392',
#   'username': 'moanfIeur',
#   'name': '',
#   'profile_picture': 'https://twitter.com/moanfIeur/photo',
#   'replies': 0,
#   'retweets': 0,
#   'likes': 0,
#   'is_retweet': False,
#   'posted_time': '2022-08-30T23:48:04+00:00',
#   'content': 'Tinggal cari duitnya aja ini mah kalo di Thailand bisa pake Qris',
#   'hashtags': [],
#   'mentions': [],
#   'images': [],
#   'videos': [],
#   'tweet_url': 'https://twitter.com/moanfIeur/status/1564761905410875392',
#   'link': ''}}

# %% [markdown]
# #### Pretty print json/dict object

# %%
import pprint
pprint.pprint(thailand_json)
# Out:
# {'1564761905410875392': {'content': 'Tinggal cari duitnya aja ini mah kalo di '
#                                     'Thailand bisa pake Qris',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': [],
#                          'name': '',
#                          'posted_time': '2022-08-30T23:48:04+00:00',
#                          'profile_picture': 'https://twitter.com/moanfIeur/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564761905410875392',
#                          'tweet_url': 'https://twitter.com/moanfIeur/status/1564761905410875392',
#                          'username': 'moanfIeur',
#                          'videos': []},
#  '1564761944061382656': {'content': 'Padahal berharap pertama lawan Thailand '
#                                     'atau Filipina',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Irfan Rapiansyah',
#                          'posted_time': '2022-08-30T23:48:13+00:00',
#                          'profile_picture': 'https://twitter.com/IrfanHazard10/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564761944061382656',
#                          'tweet_url': 'https://twitter.com/IrfanHazard10/status/1564761944061382656',
#                          'username': 'IrfanHazard10',
#                          'videos': []},
#  '1564762027507458049': {'content': '@blueeyellowww\n'
#                                     ' Yuk nabung buat ke Thailand wkwk',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': ['blueeyellowww'],
#                          'name': 'Dandelion',
#                          'posted_time': '2022-08-30T23:48:33+00:00',
#                          'profile_picture': 'https://twitter.com/taraxacumyx/photo',
#                          'replies': 1,
#                          'retweets': 0,
#                          'tweet_id': '1564762027507458049',
#                          'tweet_url': 'https://twitter.com/taraxacumyx/status/1564762027507458049',
#                          'username': 'taraxacumyx',
#                          'videos': []},
#  '1564762170277052418': {'content': 'เป๊ก ปาล์มมี่ | Disney+ Hotstar Thailand '
#                                     'https://youtu.be/541HmrdzmHc via \n'
#                                     '@YouTube\n'
#                                     '  #เปกผลิตโชค #PeckPaLitChoke',
#                          'hashtags': ['เปกผล', 'PeckPaLitChoke'],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': ['YouTube'],
#                          'name': 'palito..showcase',
#                          'posted_time': '2022-08-30T23:49:07+00:00',
#                          'profile_picture': 'https://twitter.com/AntzAntz1/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564762170277052418',
#                          'tweet_url': 'https://twitter.com/AntzAntz1/status/1564762170277052418',
#                          'username': 'AntzAntz1',
#                          'videos': []},
#  '1564762335192940544': {'content': 'how about Friday at 11 am? that way it '
#                                     'will  be 10pm in Thailand & we can invite '
#                                     'that crew.\n'
#                                     '@blossom_melonn',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 1,
#                          'link': '',
#                          'mentions': ['blossom_melonn'],
#                          'name': 'NFTeVe',
#                          'posted_time': '2022-08-30T23:49:47+00:00',
#                          'profile_picture': 'https://twitter.com/NFTLadyEve/photo',
#                          'replies': 1,
#                          'retweets': 0,
#                          'tweet_id': '1564762335192940544',
#                          'tweet_url': 'https://twitter.com/NFTLadyEve/status/1564762335192940544',
#                          'username': 'NFTLadyEve',
#                          'videos': []},
#  '1564762341324992513': {'content': 'Can you help me?\n'
#                                     '\n'
#                                     'tracking number\n'
#                                     'FMP200001150XX\n'
#                                     '\n'
#                                     'Does anyone know a shipping company in '
#                                     'Thailand that handles this number?\n'
#                                     "I'm in trouble with no reply even if I "
#                                     'contact the caller \n'
#                                     '\n'
#                                     '#Zunshine',
#                          'hashtags': ['Zunshine'],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 32,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'ZeePruk_JapanFC（Rest）',
#                          'posted_time': '2022-08-30T23:49:48+00:00',
#                          'profile_picture': 'https://twitter.com/Zeepruk_jfc/photo',
#                          'replies': 2,
#                          'retweets': 54,
#                          'tweet_id': '1564762341324992513',
#                          'tweet_url': 'https://twitter.com/Zeepruk_jfc/status/1564762341324992513',
#                          'username': 'Zeepruk_jfc',
#                          'videos': []},
#  '1564763050477244417': {'content': '@NaEMwi\n @jaemwinner\n @JAEMIN_THAILAND',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': ['NaEMwi',
#                                       'jaemwinner',
#                                       'JAEMIN_THAILAND'],
#                          'name': 'wonyoungiii | surprise cutie',
#                          'posted_time': '2022-08-30T23:52:37+00:00',
#                          'profile_picture': 'https://twitter.com/jaemmrchv/photo',
#                          'replies': 0,
#                          'retweets': 1,
#                          'tweet_id': '1564763050477244417',
#                          'tweet_url': 'https://twitter.com/jaemmrchv/status/1564763050477244417',
#                          'username': 'jaemmrchv',
#                          'videos': []},
#  '1564763141589897217': {'content': 'we need more ten vlogs in thailand...a '
#                                     'girl can dream',
#                          'hashtags': [],
#                          'images': ['https://pbs.twimg.com/media/EDNptiHUEAAqdwm?format=jpg&name=small'],
#                          'is_retweet': True,
#                          'likes': 3,
#                          'link': '',
#                          'mentions': [],
#                          'name': '',
#                          'posted_time': '2022-08-30T23:52:59+00:00',
#                          'profile_picture': 'https://twitter.com/Iovelydoll/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564763141589897217',
#                          'tweet_url': 'https://twitter.com/Iovelydoll/status/1564763141589897217',
#                          'username': 'Iovelydoll',
#                          'videos': []},
#  '1564763185244426240': {'content': 'พร้อมครัช\n'
#                                     '\n'
#                                     'Please,come to thailand.\n'
#                                     ' \n'
#                                     '\n'
#                                     '#JAYB #제이비 \n'
#                                     '@jaybnow_hr\n'
#                                     '#GOT7 #갓세븐 \n'
#                                     '@GOT7\n'
#                                     '#CDNZA \n'
#                                     '@cdnzarecords\n'
#                                     '#Def',
#                          'hashtags': ['JAYB',
#                                       '제이비',
#                                       'GOT7',
#                                       '갓세븐',
#                                       'CDNZA',
#                                       'Def'],
#                          'images': ['https://pbs.twimg.com/media/FbcmB6RUEAA75m6?format=jpg&name=small'],
#                          'is_retweet': True,
#                          'likes': 7,
#                          'link': '',
#                          'mentions': ['jaybnow_hr', 'GOT7', 'cdnzarecords'],
#                          'name': 'Jay Bee',
#                          'posted_time': '2022-08-30T23:53:09+00:00',
#                          'profile_picture': 'https://twitter.com/Jay_beebee/photo',
#                          'replies': 1,
#                          'retweets': 7,
#                          'tweet_id': '1564763185244426240',
#                          'tweet_url': 'https://twitter.com/Jay_beebee/status/1564763185244426240',
#                          'username': 'Jay_beebee',
#                          'videos': []},
#  '1564763292354355200': {'content': '- please engage\n'
#                                     '\n'
#                                     'ELLE Thailand  \n'
#                                     ' https://instagram.com/p/Ch02SH7hGpq/ \n'
#                                     '  https://instagram.com/p/Ch0xESZB1kr/ \n'
#                                     '\n'
#                                     '#LISA #LALISA #Money',
#                          'hashtags': ['LISA', 'LALISA', 'Money'],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 5,
#                          'link': 'https://t.co/6aZ539h9RK',
#                          'mentions': [],
#                          'name': 'LDN327',
#                          'posted_time': '2022-08-30T23:53:35+00:00',
#                          'profile_picture': 'https://twitter.com/LDN327/photo',
#                          'replies': 1,
#                          'retweets': 7,
#                          'tweet_id': '1564763292354355200',
#                          'tweet_url': 'https://twitter.com/LDN327/status/1564763292354355200',
#                          'username': 'LDN327',
#                          'videos': []},
#  '1564763303989366784': {'content': 'Kalo di thailand bukan dong :)',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Cynthia Dewi',
#                          'posted_time': '2022-08-30T23:53:38+00:00',
#                          'profile_picture': 'https://twitter.com/aisseutea/photo',
#                          'replies': 1,
#                          'retweets': 0,
#                          'tweet_id': '1564763303989366784',
#                          'tweet_url': 'https://twitter.com/aisseutea/status/1564763303989366784',
#                          'username': 'aisseutea',
#                          'videos': []},
#  '1564763389058027521': {'content': 'woo.ddadda in thailand ',
#                          'hashtags': [],
#                          'images': ['https://pbs.twimg.com/media/FbcoAO_XkAA-Isn?format=jpg&name=360x360',
#                                     'https://pbs.twimg.com/media/FbcoAPDXEAYc26T?format=jpg&name=360x360'],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'em ☾',
#                          'posted_time': '2022-08-30T23:53:58+00:00',
#                          'profile_picture': 'https://twitter.com/starrykws/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564763389058027521',
#                          'tweet_url': 'https://twitter.com/starrykws/status/1564763389058027521',
#                          'username': 'starrykws',
#                          'videos': []},
#  '1564763407818952705': {'content': '= and the French people and also '
#                                     "Thailand's people that have not thrown "
#                                     "lethal military barracks gas at an 'Enemy "
#                                     "of Thought' are the races to not survive "
#                                     'a space race Masterclass',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'j',
#                          'posted_time': '2022-08-30T23:54:02+00:00',
#                          'profile_picture': 'https://twitter.com/SarahJa56317435/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564763407818952705',
#                          'tweet_url': 'https://twitter.com/SarahJa56317435/status/1564763407818952705',
#                          'username': 'SarahJa56317435',
#                          'videos': []},
#  '1564763553130655744': {'content': 'Can fluf merch send to Asian countries '
#                                     'like Japan or Thailand?',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 7,
#                          'link': '',
#                          'mentions': [],
#                          'name': '¢нαк.єтн',
#                          'posted_time': '2022-08-30T23:54:37+00:00',
#                          'profile_picture': 'https://twitter.com/chak4793/photo',
#                          'replies': 1,
#                          'retweets': 0,
#                          'tweet_id': '1564763553130655744',
#                          'tweet_url': 'https://twitter.com/chak4793/status/1564763553130655744',
#                          'username': 'chak4793',
#                          'videos': []},
#  '1564763673662464003': {'content': 'I knew I heard the beginning speech that '
#                                     'Lisa had an Australian accent.  It is not '
#                                     'that she is from Australia but '
#                                     'Thailand... here is the explanation...',
#                          'hashtags': [],
#                          'images': ['https://pbs.twimg.com/media/FbcoKGTWAAAA0-D?format=png&name=900x900'],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'ⒷⓉⓈARMY할머니ᴶᴹᴶᴷ³ᴶ',
#                          'posted_time': '2022-08-30T23:55:06+00:00',
#                          'profile_picture': 'https://twitter.com/JaeJazee/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564763673662464003',
#                          'tweet_url': 'https://twitter.com/JaeJazee/status/1564763673662464003',
#                          'username': 'JaeJazee',
#                          'videos': []},
#  '1564763679232405504': {'content': 'right? 2 years ago he is just a simple '
#                                     'born and raised guy from thailand who can '
#                                     'barely speak thai and likes to do diys '
#                                     'and make everything about math i just '
#                                     'love how authentic he is hahaha have you '
#                                     'seen his 1000 push ups one? ',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 1,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'shi bangs',
#                          'posted_time': '2022-08-30T23:55:07+00:00',
#                          'profile_picture': 'https://twitter.com/sixhav/photo',
#                          'replies': 1,
#                          'retweets': 0,
#                          'tweet_id': '1564763679232405504',
#                          'tweet_url': 'https://twitter.com/sixhav/status/1564763679232405504',
#                          'username': 'sixhav',
#                          'videos': []},
#  '1564763729967054848': {'content': 'วันนี้วันสุดท้ายของการโหวต รางวัล '
#                                     'Outstanding Asian Star Thailand #SDA2022 '
#                                     'ให้น้องพีพีแล้วนะคะ \n'
#                                     'มาพาน้องไปรับถ้วยรางวัล2ปีซ้อนกันค่ะ\n'
#                                     '#voteforppkritt \n'
#                                     '#ppkritt',
#                          'hashtags': ['SDA2022', 'voteforppkritt', 'ppkritt'],
#                          'images': ['https://pbs.twimg.com/media/FbcoUQAaQAAIFME?format=jpg&name=small'],
#                          'is_retweet': False,
#                          'likes': 15,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'o_Rung_o',
#                          'posted_time': '2022-08-30T23:55:19+00:00',
#                          'profile_picture': 'https://twitter.com/o_rung_o1/photo',
#                          'replies': 0,
#                          'retweets': 28,
#                          'tweet_id': '1564763729967054848',
#                          'tweet_url': 'https://twitter.com/o_rung_o1/status/1564763729967054848',
#                          'username': 'o_rung_o1',
#                          'videos': []},
#  '1564763746463105026': {'content': 'How far would you go to save the family '
#                                     'farm and keep your siblings in school? '
#                                     "Read what Lek did in 'Behind The Smile, "
#                                     "the story of Lek, a bar girl in Pattaya' "
#                                     'by Owen Jones! '
#                                     'https://smarturl.it/BTS-boxset?IQid=SJB-lw-thailand… '
#                                     '#pattaya #Thailand Please retweet',
#                          'hashtags': ['pattaya', 'Thailand'],
#                          'images': ['https://pbs.twimg.com/media/FbcoVHpWIAEh_R0?format=jpg&name=small'],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Lek',
#                          'posted_time': '2022-08-30T23:55:23+00:00',
#                          'profile_picture': 'https://twitter.com/lekwilliams/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564763746463105026',
#                          'tweet_url': 'https://twitter.com/lekwilliams/status/1564763746463105026',
#                          'username': 'lekwilliams',
#                          'videos': []},
#  '1564763775403712513': {'content': 'And I thought Thailand was absolutely '
#                                     'democratic?',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Onside',
#                          'posted_time': '2022-08-30T23:55:30+00:00',
#                          'profile_picture': 'https://twitter.com/Onside10900651/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564763775403712513',
#                          'tweet_url': 'https://twitter.com/Onside10900651/status/1564763775403712513',
#                          'username': 'Onside10900651',
#                          'videos': []},
#  '1564763907700531202': {'content': '#ICYMI  On the Frontline. Crude Power in '
#                                     'Thailand’s 2014 Coup: Old Soldiers Almost '
#                                     'Die',
#                          'hashtags': ['ICYMI'],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': 'https://t.co/OYQzv4BSm9',
#                          'mentions': [],
#                          'name': 'Discover Society',
#                          'posted_time': '2022-08-30T23:56:02+00:00',
#                          'profile_picture': 'https://twitter.com/DiscoverSoc/photo',
#                          'replies': 0,
#                          'retweets': 1,
#                          'tweet_id': '1564763907700531202',
#                          'tweet_url': 'https://twitter.com/DiscoverSoc/status/1564763907700531202',
#                          'username': 'DiscoverSoc',
#                          'videos': []},
#  '1564764028014313472': {'content': 'With the recent news of the SCB X-Bitkub '
#                                     'deal falling apart and the Zipmex '
#                                     "incident, investors in Thailand's digital "
#                                     'currency market are facing a negative '
#                                     'outlook',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 3,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Knightly News',
#                          'posted_time': '2022-08-30T23:56:30+00:00',
#                          'profile_picture': 'https://twitter.com/Livetradingnews/photo',
#                          'replies': 0,
#                          'retweets': 2,
#                          'tweet_id': '1564764028014313472',
#                          'tweet_url': 'https://twitter.com/Livetradingnews/status/1564764028014313472',
#                          'username': 'Livetradingnews',
#                          'videos': []},
#  '1564764274098323456': {'content': 'Listening to #faraway the title track of '
#                                     '#theotherside album by #MarkTuan \n'
#                                     '@marktuan\n'
#                                     ' while traveling to Thailand',
#                          'hashtags': ['faraway', 'theotherside', 'MarkTuan'],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': ['marktuan'],
#                          'name': 'thiti',
#                          'posted_time': '2022-08-30T23:57:29+00:00',
#                          'profile_picture': 'https://twitter.com/ThThitikarn61/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564764274098323456',
#                          'tweet_url': 'https://twitter.com/ThThitikarn61/status/1564764274098323456',
#                          'username': 'ThThitikarn61',
#                          'videos': []},
#  '1564764361742110720': {'content': 'Good morning  world! And goodmorning to '
#                                     'you too #DonnyPangilinan, enjoy Thailand '
#                                     'babe and please do take selfies out '
#                                     'there!, pagod nakong makikitang sapatos '
#                                     'pa din nasa igs mo!!',
#                          'hashtags': ['DonnyPangilinan'],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 18,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'nutri(BUSY SI ENGR.)| SoliD',
#                          'posted_time': '2022-08-30T23:57:50+00:00',
#                          'profile_picture': 'https://twitter.com/nato_tonyo11/photo',
#                          'replies': 0,
#                          'retweets': 2,
#                          'tweet_id': '1564764361742110720',
#                          'tweet_url': 'https://twitter.com/nato_tonyo11/status/1564764361742110720',
#                          'username': 'nato_tonyo11',
#                          'videos': []},
#  '1564764445825458181': {'content': 'Trend twitter update \n'
#                                     '\n'
#                                     'Top Twitter influencers in Thailand '
#                                     'today \n'
#                                     '#4 \n'
#                                     '@ohmpawatt\n'
#                                     'Influence Score: 19442\n'
#                                     '7 top tweets\n'
#                                     '25182 retweets\n'
#                                     '\n'
#                                     'https://etrenders.com/trendsetters/Thailand…\n'
#                                     '#ohmpawat #ยิ้ม5พันของโอมภวัต',
#                          'hashtags': ['4', 'ohmpawat', 'ย'],
#                          'images': ['https://pbs.twimg.com/media/Fbco99jWIAEd3Oe?format=jpg&name=small',
#                                     'https://pbs.twimg.com/media/Fbco-JwWYAE7oLy?format=jpg&name=small'],
#                          'is_retweet': False,
#                          'likes': 143,
#                          'link': '',
#                          'mentions': ['ohmpawatt'],
#                          'name': 'OhmPawat International',
#                          'posted_time': '2022-08-30T23:58:10+00:00',
#                          'profile_picture': 'https://twitter.com/OhmPawatInter/photo',
#                          'replies': 0,
#                          'retweets': 99,
#                          'tweet_id': '1564764445825458181',
#                          'tweet_url': 'https://twitter.com/OhmPawatInter/status/1564764445825458181',
#                          'username': 'OhmPawatInter',
#                          'videos': []},
#  '1564764468277612549': {'content': 'ALIEN HOUSE is a story of love, hope and '
#                                     'alien intervention set in Wales, Thailand '
#                                     "and Inner Space. It's a #fantasy story "
#                                     'about #extraterrestrial contact and the '
#                                     'conflict between a man and his inner '
#                                     'voice or alter ego. William is not sure '
#                                     "if he's going mad "
#                                     'https://smarturl.it/alien-house-eng?IQid=jbmegan…',
#                          'hashtags': ['fantasy', 'extraterrestrial'],
#                          'images': ['https://pbs.twimg.com/media/Fbco_bSXEAMcDOZ?format=jpg&name=small'],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Megan',
#                          'posted_time': '2022-08-30T23:58:15+00:00',
#                          'profile_picture': 'https://twitter.com/Megan_and_Grrr/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564764468277612549',
#                          'tweet_url': 'https://twitter.com/Megan_and_Grrr/status/1564764468277612549',
#                          'username': 'Megan_and_Grrr',
#                          'videos': []},
#  '1564764710804897792': {'content': 'You can live some places for next to '
#                                     'nothing, believe it or not. I pay $300 a '
#                                     'month for a really nice apartment in '
#                                     'Thailand. All utilities included. No '
#                                     'deposit. Close to the beach. Live music '
#                                     'clubs everywhere. Meals are about $2',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 1,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'Bryan',
#                          'posted_time': '2022-08-30T23:59:13+00:00',
#                          'profile_picture': 'https://twitter.com/Bryan62766077/photo',
#                          'replies': 1,
#                          'retweets': 0,
#                          'tweet_id': '1564764710804897792',
#                          'tweet_url': 'https://twitter.com/Bryan62766077/status/1564764710804897792',
#                          'username': 'Bryan62766077',
#                          'videos': []},
#  '1564764845685280772': {'content': 'The latest The Pattaya Daily! '
#                                     'http://thepattayadaily.com Thanks to \n'
#                                     '@PopeKael\n'
#                                     ' @ASEANNOWTH\n'
#                                     ' #thailand #pattaya',
#                          'hashtags': ['thailand', 'pattaya'],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 0,
#                          'link': '',
#                          'mentions': ['PopeKael', 'ASEANNOWTH'],
#                          'name': 'The Pattaya Daily',
#                          'posted_time': '2022-08-30T23:59:45+00:00',
#                          'profile_picture': 'https://twitter.com/DailyPattaya/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564764845685280772',
#                          'tweet_url': 'https://twitter.com/DailyPattaya/status/1564764845685280772',
#                          'username': 'DailyPattaya',
#                          'videos': []},
#  '1564764866598080513': {'content': 'Tomb Raider Underworld | Thailand \n'
#                                     '#VirtualPhotography \n'
#                                     '@tombraider\n'
#                                     ' @crystaldynamics',
#                          'hashtags': ['VirtualPhotography'],
#                          'images': ['https://pbs.twimg.com/media/FbcpF-FXkAIlqTS?format=jpg&name=small'],
#                          'is_retweet': False,
#                          'likes': 2,
#                          'link': '',
#                          'mentions': ['tombraider', 'crystaldynamics'],
#                          'name': 'DavSmith / Virtual Photography',
#                          'posted_time': '2022-08-30T23:59:50+00:00',
#                          'profile_picture': 'https://twitter.com/DavSmithVP/photo',
#                          'replies': 0,
#                          'retweets': 0,
#                          'tweet_id': '1564764866598080513',
#                          'tweet_url': 'https://twitter.com/DavSmithVP/status/1564764866598080513',
#                          'username': 'DavSmithVP',
#                          'videos': []},
#  '1564764893038882816': {'content': 'Thanks for asking! Yes, we will support '
#                                     'shipping to most countries, including '
#                                     'Japan and Thailand. ',
#                          'hashtags': [],
#                          'images': [],
#                          'is_retweet': False,
#                          'likes': 7,
#                          'link': '',
#                          'mentions': [],
#                          'name': 'MATT HUNTΞR',
#                          'posted_time': '2022-08-30T23:59:57+00:00',
#                          'profile_picture': 'https://twitter.com/matthunter/photo',
#                          'replies': 2,
#                          'retweets': 1,
#                          'tweet_id': '1564764893038882816',
#                          'tweet_url': 'https://twitter.com/matthunter/status/1564764893038882816',
#                          'username': 'matthunter',
#                          'videos': []}}

# %% [markdown]
# ทดสอบอื่นๆ

# %%
thailand_json.keys()
# Out:
# dict_keys(['1564764893038882816', '1564764866598080513', '1564764845685280772', '1564764710804897792', '1564764468277612549', '1564764445825458181', '1564764361742110720', '1564764274098323456', '1564764028014313472', '1564763907700531202', '1564763775403712513', '1564763746463105026', '1564763729967054848', '1564763679232405504', '1564763673662464003', '1564763553130655744', '1564763407818952705', '1564763389058027521', '1564763303989366784', '1564763292354355200', '1564763185244426240', '1564763141589897217', '1564763050477244417', '1564762341324992513', '1564762335192940544', '1564762170277052418', '1564762027507458049', '1564761944061382656', '1564761905410875392'])

# %%
first_key = list(thailand_json.keys())[0]
thailand_json[first_key]
# Out:
# {'tweet_id': '1564764893038882816',
#  'username': 'matthunter',
#  'name': 'MATT HUNTΞR',
#  'profile_picture': 'https://twitter.com/matthunter/photo',
#  'replies': 2,
#  'retweets': 1,
#  'likes': 7,
#  'is_retweet': False,
#  'posted_time': '2022-08-30T23:59:57+00:00',
#  'content': 'Thanks for asking! Yes, we will support shipping to most countries, including Japan and Thailand. ',
#  'hashtags': [],
#  'mentions': [],
#  'images': [],
#  'videos': [],
#  'tweet_url': 'https://twitter.com/matthunter/status/1564764893038882816',
#  'link': ''}

# %% [markdown]
# Possible approaches:
# * In fact, `pandas` has `pandas.read_json(<file_dir>)` function to read json file into dataframe
# * As we create a data dict, we can also read our data dict into a pandas dataframe

# %%
import pandas as pd
from io import StringIO

# %%
thailand_df = pd.read_json(StringIO(d), orient='index')

# %%
thailand_df
# Out:
#                                           tweet_id         username  \
# 2019-08-02 16:54:53.038882816  1564764893038882816       matthunter
# 2019-08-02 16:54:26.598080513  1564764866598080512       DavSmithVP
# 2019-08-02 16:54:05.685280772  1564764845685280768     DailyPattaya
# 2019-08-02 16:51:50.804897792  1564764710804897792    Bryan62766077
# 2019-08-02 16:47:48.277612549  1564764468277612544   Megan_and_Grrr
# 2019-08-02 16:47:25.825458181  1564764445825458176    OhmPawatInter
# 2019-08-02 16:46:01.742110720  1564764361742110720     nato_tonyo11
# 2019-08-02 16:44:34.098323456  1564764274098323456    ThThitikarn61
# 2019-08-02 16:40:28.014313472  1564764028014313472  Livetradingnews
# 2019-08-02 16:38:27.700531202  1564763907700531200      DiscoverSoc
# 2019-08-02 16:36:15.403712513  1564763775403712512   Onside10900651
# 2019-08-02 16:35:46.463105026  1564763746463105024      lekwilliams
# 2019-08-02 16:35:29.967054848  1564763729967054848        o_rung_o1
# 2019-08-02 16:34:39.232405504  1564763679232405504           sixhav
# 2019-08-02 16:34:33.662464003  1564763673662464000         JaeJazee
# 2019-08-02 16:32:33.130655744  1564763553130655744         chak4793
# 2019-08-02 16:30:07.818952705  1564763407818952704  SarahJa56317435
# 2019-08-02 16:29:49.058027521  1564763389058027520        starrykws
# 2019-08-02 16:28:23.989366784  1564763303989366784        aisseutea
# 2019-08-02 16:29:49.058027521  https://twitter.com/starrykws/status/156476338...
# 2019-08-02 16:28:23.989366784  https://twitter.com/aisseutea/status/156476330...
# 2019-08-02 16:28:12.354355200  https://twitter.com/LDN327/status/156476329235...
# 2019-08-02 16:26:25.244426240  https://twitter.com/Jay_beebee/status/15647631...
# 2019-08-02 16:25:41.589897217  https://twitter.com/Iovelydoll/status/15647631...
# 2019-08-02 16:24:10.477244417  https://twitter.com/jaemmrchv/status/156476305...
# 2019-08-02 16:12:21.324992513  https://twitter.com/Zeepruk_jfc/status/1564762...
# 2019-08-02 16:12:15.192940544  https://twitter.com/NFTLadyEve/status/15647623...
# 2019-08-02 16:09:30.277052418  https://twitter.com/AntzAntz1/status/156476217...
# 2019-08-02 16:07:07.507458049  https://twitter.com/taraxacumyx/status/1564762...
# 2019-08-02 16:05:44.061382656  https://twitter.com/IrfanHazard10/status/15647...
# 2019-08-02 16:05:05.410875392  https://twitter.com/moanfIeur/status/156476190...
#
#                                                   link
# 2019-08-02 16:54:53.038882816
# 2019-08-02 16:54:26.598080513
# 2019-08-02 16:54:05.685280772
# 2019-08-02 16:51:50.804897792
# 2019-08-02 16:47:48.277612549
# 2019-08-02 16:47:25.825458181
# 2019-08-02 16:46:01.742110720
# 2019-08-02 16:44:34.098323456
# 2019-08-02 16:40:28.014313472
# 2019-08-02 16:38:27.700531202  https://t.co/OYQzv4BSm9
# 2019-08-02 16:36:15.403712513
# 2019-08-02 16:35:46.463105026
# 2019-08-02 16:35:29.967054848
# 2019-08-02 16:34:39.232405504
# 2019-08-02 16:34:33.662464003
# 2019-08-02 16:32:33.130655744
# 2019-08-02 16:30:07.818952705
# 2019-08-02 16:29:49.058027521
# 2019-08-02 16:28:23.989366784
# 2019-08-02 16:28:12.354355200  https://t.co/6aZ539h9RK
# 2019-08-02 16:26:25.244426240
# 2019-08-02 16:25:41.589897217
# 2019-08-02 16:24:10.477244417
# 2019-08-02 16:12:21.324992513
# 2019-08-02 16:12:15.192940544
# 2019-08-02 16:09:30.277052418
# 2019-08-02 16:07:07.507458049
# 2019-08-02 16:05:44.061382656
# 2019-08-02 16:05:05.410875392

# %% [markdown]
# ### Your report
# * The total number of tweets collected in the file:
# * The content of the first tweet:
# * Is the first tweet contained any hashtags or mentions?
# * Collect all hashtags related to Thailand from this data
# * Find the most popular tweets in your collection of tweets, i.e. the tweets with the largest number of retweet/replies/likes counts
#     * You are free to define your own popularity metric
# * Display the top 5 tweets that are the most popular among your collection
# * Create a word cloud of words in the contents; however, we note that this word cloud is not a good representation of Thailand as the data size is small

# %%
# ----------------- Your code here -----------------

# %%
th_df = thailand_df.set_index([pd.Index(range(29))])

# %%
th_df

# %% [markdown]
# * The total number of tweets collected in the file:

# %%
thailand_df.shape
# Out:
# (29, 16)

# %% [markdown]
# * The content of the first tweet:

# %%
content = th_df.iloc[:1, 9:10]

# %%
print(content.loc[0, 'content'])
# Out:
# Thanks for asking! Yes, we will support shipping to most countries, including Japan and Thailand.

# %%
thailand_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 29 entries, 2019-08-02 16:54:53.038882816 to 2019-08-02 16:05:05.410875392
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   tweet_id         29 non-null     int64
#  1   username         29 non-null     object
#  2   name             29 non-null     object
#  3   profile_picture  29 non-null     object
#  4   replies          29 non-null     int64
#  5   retweets         29 non-null     int64
#  6   likes            29 non-null     int64
#  7   is_retweet       29 non-null     bool
#  8   posted_time      29 non-null     datetime64[ns, UTC]
#  9   content          29 non-null     object
#  10  hashtags         29 non-null     object
#  11  mentions         29 non-null     object
#  12  images           29 non-null     object
#  13  videos           29 non-null     object
#  14  tweet_url        29 non-null     object
#  15  link             29 non-null     object
# dtypes: bool(1), datetime64[ns, UTC](1), int64(4), object(10)
# memory usage: 3.7+ KB

# %% [markdown]
# * Is the first tweet contained any hashtags or mentions?

# %%
ht_mt = th_df.iloc[:2, 10:12]

# %%
print(ht_mt.loc[1][:2])
# Out:
# hashtags             [VirtualPhotography]
# mentions    [tombraider, crystaldynamics]
# Name: 1, dtype: object

# %% [markdown]
# * Find the most popular tweets in your collection of tweets, i.e. the tweets with the largest number of retweet/replies/likes counts
#     * You are free to define your own popularity metric

# %% [markdown]
# * Display the top 5 tweets that are the most popular among your collection

# %% [markdown]
# * Create a word cloud of words in the contents; however, we note that this word cloud is not a good representation of Thailand as the data size is small

# %%
contents = " ".join([thailand_json[key]['content'] for key in thailand_json.keys()])
print(contents)
# Out:
# Thanks for asking! Yes, we will support shipping to most countries, including Japan and Thailand.  Tomb Raider Underworld | Thailand
# #VirtualPhotography
# @tombraider
#  @crystaldynamics The latest The Pattaya Daily! http://thepattayadaily.com Thanks to
# @PopeKael
#  @ASEANNOWTH
#  #thailand #pattaya You can live some places for next to nothing, believe it or not. I pay $300 a month for a really nice apartment in Thailand. All utilities included. No deposit. Close to the beach. Live music clubs everywhere. Meals are about $2 ALIEN HOUSE is a story of love, hope and alien intervention set in Wales, Thailand and Inner Space. It's a #fantasy story about #extraterrestrial contact and the conflict between a man and his inner voice or alter ego. William is not sure if he's going mad https://smarturl.it/alien-house-eng?IQid=jbmegan… Trend twitter update
#
# Top Twitter influencers in Thailand today
# #4
# @ohmpawatt
# Influence Score: 19442
# 7 top tweets
# 25182 retweets
#
# https://etrenders.com/trendsetters/Thailand…
# #ohmpawat #ยิ้ม5พันของโอมภวัต Good morning  world! And goodmorning to you too #DonnyPangilinan, enjoy Thailand babe and please do take selfies out there!, pagod nakong makikitang sapatos pa din nasa igs mo!! Listening to #faraway the title track of #theotherside album by #MarkTuan
# @marktuan
#  while traveling to Thailand With the recent news of the SCB X-Bitkub deal falling apart and the Zipmex incident, investors in Thailand's digital currency market are facing a negative outlook #ICYMI  On the Frontline. Crude Power in Thailand’s 2014 Coup: Old Soldiers Almost Die And I thought Thailand was absolutely democratic? How far would you go to save the family farm and keep your siblings in school? Read what Lek did in 'Behind The Smile, the story of Lek, a bar girl in Pattaya' by Owen Jones! https://smarturl.it/BTS-boxset?IQid=SJB-lw-thailand… #pattaya #Thailand Please retweet วันนี้วันสุดท้ายของการโหวต รางวัล Outstanding Asian Star Thailand #SDA2022 ให้น้องพีพีแล้วนะคะ
# มาพาน้องไปรับถ้วยรางวัล2ปีซ้อนกันค่ะ
# #voteforppkritt
# #ppkritt right? 2 years ago he is just a simple born and raised guy from thailand who can barely speak thai and likes to do diys and make everything about math i just love how authentic he is hahaha have you seen his 1000 push ups one?  I knew I heard the beginning speech that Lisa had an Australian accent.  It is not that she is from Australia but Thailand... here is the explanation... Can fluf merch send to Asian countries like Japan or Thailand? = and the French people and also Thailand's people that have not thrown lethal military barracks gas at an 'Enemy of Thought' are the races to not survive a space race Masterclass woo.ddadda in thailand  Kalo di thailand bukan dong :) - please engage
#
# ELLE Thailand
#  https://instagram.com/p/Ch02SH7hGpq/
#   https://instagram.com/p/Ch0xESZB1kr/
#
# #LISA #LALISA #Money พร้อมครัช
#
# Please,come to thailand.
#
#
# #JAYB #제이비
# @jaybnow_hr
# #GOT7 #갓세븐
# @GOT7
# #CDNZA
# @cdnzarecords
# #Def we need more ten vlogs in thailand...a girl can dream @NaEMwi
#  @jaemwinner
#  @JAEMIN_THAILAND Can you help me?
#
# tracking number
# FMP200001150XX
#
# Does anyone know a shipping company in Thailand that handles this number?
# I'm in trouble with no reply even if I contact the caller
#
# #Zunshine how about Friday at 11 am? that way it will  be 10pm in Thailand & we can invite that crew.
# @blossom_melonn เป๊ก ปาล์มมี่ | Disney+ Hotstar Thailand https://youtu.be/541HmrdzmHc via
# @YouTube
#   #เปกผลิตโชค #PeckPaLitChoke @blueeyellowww
#  Yuk nabung buat ke Thailand wkwk Padahal berharap pertama lawan Thailand atau Filipina Tinggal cari duitnya aja ini mah kalo di Thailand bisa pake Qris

# %%
# Create and generate a word cloud image:
wordcloud = WordCloud().generate(contents)
wordcloud

# %%
# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %% [markdown]
# Note: ไม่ต้องรายงานส่วนนี้ในสไลด์

# %% [markdown]
# ## Problem 2 Study Trip Advisor Hotel Reviews Sentiment

# %% [markdown]
# We are working with the Trip Advisor Hotel Reviews dataset. You can see the source from https://www.kaggle.com/datasets/andrewmvd/trip-advisor-hotel-reviews.

# %% [markdown]
# * Analyze the data to find out what make a hotel good or bad
# <br>You may create a tag of "positive", "negative", or "neural" sentiment first. After tagging each tweet with different sentiment, we can separate positive tweets and negative tweets. Then, it is easier to find our common patterns in positive tweets or good hotels, and vice versa.

# %%
#----------------------------------------------
# Your code starts here
# label each tweet as positive, negative, and neural sentiment
# combine tweet texts in each type
# tokenize texts
# convert to lower case
# remove stop words
# remove any other stop words, like RT
# remove punctuations
# remove other symbols?
# analyze word frequency in each sentiment type and so on
# create some data visualization for the analysis and your presentation

# %% [markdown]
# ### Report
# * How did you analyze the data?
# * What did you find in the data? (please include figures or tables in the report, but no source code)

# %% [markdown]
# ## Problem 3 Collect and Analyze Your Interesting Topic

# %% [markdown]
# * Select a topic that your group members are interested
# * Gather url from at least 3 webpages
# * Use urllib.request to retrieve data from webpage
# * Clean and find intersting patterns and information
# * Create a word cloud of your topic

# %%
#----------------------------------------------
# Your code starts here

# %% [markdown]
# ### Report
# * What did you find out about your topic? (please include figures or tables in the report, but no source code)

# %% [markdown]
# # ☃️ The End of Project 1 ☃️
